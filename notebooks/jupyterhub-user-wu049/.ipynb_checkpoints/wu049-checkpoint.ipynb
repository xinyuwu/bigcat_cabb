# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
import datetime
import simulator


scheduler = simulator.Scheduler()

scheduler.load_schedule_file(
    'schedule_files/test.sch')

scheduler.show_targets()
# Out:
# 1 :  {"name": "c3515_p19t", "ra": "17:00:53.15", "dec": "-26:10:51.72", "tags": ["gaincal"], "type": "track", "band": "l", "duration": 900}
# 2 :  {"name": "1817-254", "ra": "18:20:57.849", "dec": "-25:28:12.584", "tags": ["target"], "type": "track", "band": "l", "duration": 900}
# 3 :  {"name": "J1911-2006 | 1908-201", "ra": "19:11:9.6529", "dec": "-20:06:55.109", "tags": ["gaincal"], "type": "track", "band": "l", "duration": 300}
# 4 :  {"name": "J1833-2103", "ra": "18:33:39.915", "dec": "-21:03:40.05", "tags": ["target"], "type": "track", "band": null, "duration": 900}

# %%
date = datetime.datetime.fromisoformat('2023-03-17T12:00:00')

scheduler.plot_targets(date_time=date)
# Out:
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
import simulator
simulator = simulator.Simulator()
date = datetime.datetime.fromisoformat('2023-03-17T17:00:00')
simulator.start(date_time=date)

num = 10
for _ in range(num):
    simulator.track(scheduler=scheduler, scans=[0, 3])
# Out:
# 2023-03-17 17:00:00.000 - slewing to target for 1.88 seconds c3515_p19t at el 58.15 deg
# 2023-03-17 17:15:01.884 - tracking target for 900 seconds c3515_p19t at el 58.15 deg
# 2023-03-17 17:15:01.884 - slewing to target for 1.03 seconds c3515_p19t at el 61.40 deg
# 2023-03-17 17:30:02.912 - tracking target for 900 seconds c3515_p19t at el 61.40 deg
# 2023-03-17 17:30:02.912 - slewing to target for 1.03 seconds c3515_p19t at el 64.65 deg
# 2023-03-17 17:45:03.940 - tracking target for 900 seconds c3515_p19t at el 64.65 deg
# 2023-03-17 17:45:03.940 - slewing to target for 1.03 seconds c3515_p19t at el 67.89 deg
# 2023-03-17 18:00:04.967 - tracking target for 900 seconds c3515_p19t at el 67.89 deg
# 2023-03-17 18:00:04.967 - slewing to target for 1.03 seconds c3515_p19t at el 71.12 deg
# 2023-03-17 18:15:05.994 - tracking target for 900 seconds c3515_p19t at el 71.12 deg
# 2023-03-17 18:15:05.994 - slewing to target for 1.03 seconds c3515_p19t at el 74.33 deg
# 2023-03-17 18:30:07.021 - tracking target for 900 seconds c3515_p19t at el 74.33 deg
# 2023-03-17 18:30:07.021 - slewing to target for 1.03 seconds c3515_p19t at el 77.49 deg
# 2023-03-17 18:45:08.046 - tracking target for 900 seconds c3515_p19t at el 77.49 deg
# 2023-03-17 18:45:08.046 - slewing to target for 1.02 seconds c3515_p19t at el 80.56 deg
# 2023-03-17 19:00:09.069 - tracking target for 900 seconds c3515_p19t at el 80.56 deg
# 2023-03-17 19:00:09.069 - slewing to target for 1.02 seconds c3515_p19t at el 83.39 deg
# 2023-03-17 19:15:10.085 - tracking target for 900 seconds c3515_p19t at el 83.39 deg
# 2023-03-17 19:15:10.085 - slewing to target for 1.00 seconds c3515_p19t at el 85.49 deg
# 2023-03-17 19:30:11.083 - tracking target for 900 seconds c3515_p19t at el 85.49 deg
# 2023-03-17 19:30:11.083 - slewing to target for 1.39 seconds J1833-2103 at el 68.53 deg
# 2023-03-17 19:45:12.471 - tracking target for 900 seconds J1833-2103 at el 68.53 deg
# 2023-03-17 19:45:12.471 - slewing to target for 1.02 seconds J1833-2103 at el 71.52 deg
# 2023-03-17 20:00:13.492 - tracking target for 900 seconds J1833-2103 at el 71.52 deg
# 2023-03-17 20:00:13.492 - slewing to target for 1.02 seconds J1833-2103 at el 74.35 deg
# 2023-03-17 20:15:14.509 - tracking target for 900 seconds J1833-2103 at el 74.35 deg
# 2023-03-17 20:15:14.509 - slewing to target for 1.01 seconds J1833-2103 at el 76.93 deg
# 2023-03-17 20:30:15.518 - tracking target for 900 seconds J1833-2103 at el 76.93 deg
# 2023-03-17 20:30:15.518 - slewing to target for 1.00 seconds J1833-2103 at el 79.05 deg
# 2023-03-17 20:45:16.516 - tracking target for 900 seconds J1833-2103 at el 79.05 deg
# 2023-03-17 20:45:16.516 - slewing to target for 0.98 seconds J1833-2103 at el 80.41 deg
# 2023-03-17 21:00:17.494 - tracking target for 900 seconds J1833-2103 at el 80.41 deg
# 2023-03-17 21:00:17.494 - slewing to target for 0.95 seconds J1833-2103 at el 80.68 deg
# 2023-03-17 21:15:18.444 - tracking target for 900 seconds J1833-2103 at el 80.68 deg
# 2023-03-17 21:15:18.444 - slewing to target for 0.97 seconds J1833-2103 at el 79.77 deg
# 2023-03-17 21:30:19.410 - tracking target for 900 seconds J1833-2103 at el 79.77 deg
# 2023-03-17 21:30:19.410 - slewing to target for 0.99 seconds J1833-2103 at el 77.95 deg
# 2023-03-17 21:45:20.400 - tracking target for 900 seconds J1833-2103 at el 77.95 deg
# 2023-03-17 21:45:20.400 - slewing to target for 1.01 seconds J1833-2103 at el 75.55 deg
# 2023-03-17 22:00:21.405 - tracking target for 900 seconds J1833-2103 at el 75.55 deg

# %%
simulator.plot_el()

# %%
array = ['W102', 'W4', 'W45', 'W173', 'W196', 'W392']
simulator.plot_uv(array, 'c3515_p19t')

# %%
simulator.plot_uv(array, 'J1833-2103')

# %%
num = 10
for _ in range(num):
    simulator.track(scheduler=scheduler, scans=[0, 3])
# Out:
# 2023-03-17 22:00:21.405 - slewing to target for 1.53 seconds c3515_p19t at el 55.33 deg
# 2023-03-17 22:15:22.940 - tracking target for 900 seconds c3515_p19t at el 55.33 deg
# 2023-03-17 22:15:22.940 - slewing to target for 1.33 seconds J1833-2103 at el 69.89 deg
# 2023-03-17 22:30:24.265 - tracking target for 900 seconds J1833-2103 at el 69.89 deg
# 2023-03-17 22:30:24.265 - slewing to target for 1.58 seconds c3515_p19t at el 48.85 deg
# 2023-03-17 22:45:25.843 - tracking target for 900 seconds c3515_p19t at el 48.85 deg
# 2023-03-17 22:45:25.843 - slewing to target for 1.33 seconds J1833-2103 at el 63.71 deg
# 2023-03-17 23:00:27.176 - tracking target for 900 seconds J1833-2103 at el 63.71 deg
# 2023-03-17 23:00:27.176 - slewing to target for 1.59 seconds c3515_p19t at el 42.41 deg
# 2023-03-17 23:15:28.768 - tracking target for 900 seconds c3515_p19t at el 42.41 deg
# 2023-03-17 23:15:28.768 - slewing to target for 1.33 seconds J1833-2103 at el 57.33 deg
# 2023-03-17 23:30:30.103 - tracking target for 900 seconds J1833-2103 at el 57.33 deg
# 2023-03-17 23:30:30.103 - slewing to target for 1.59 seconds c3515_p19t at el 36.02 deg
# 2023-03-17 23:45:31.696 - tracking target for 900 seconds c3515_p19t at el 36.02 deg
# 2023-03-17 23:45:31.696 - slewing to target for 1.33 seconds J1833-2103 at el 50.86 deg
# 2023-03-18 00:00:33.028 - tracking target for 900 seconds J1833-2103 at el 50.86 deg
# 2023-03-18 00:00:33.028 - slewing to target for 1.59 seconds c3515_p19t at el 29.69 deg
# 2023-03-18 00:15:34.614 - tracking target for 900 seconds c3515_p19t at el 29.69 deg
# 2023-03-18 00:15:34.614 - slewing to target for 1.33 seconds J1833-2103 at el 44.36 deg
# 2023-03-18 00:30:35.942 - tracking target for 900 seconds J1833-2103 at el 44.36 deg
# 2023-03-18 00:30:35.942 - slewing to target for 1.57 seconds c3515_p19t at el 23.45 deg
# 2023-03-18 00:45:37.513 - tracking target for 900 seconds c3515_p19t at el 23.45 deg
# 2023-03-18 00:45:37.513 - slewing to target for 1.32 seconds J1833-2103 at el 37.87 deg
# 2023-03-18 01:00:38.835 - tracking target for 900 seconds J1833-2103 at el 37.87 deg
# 2023-03-18 01:00:38.835 - slewing to target for 1.55 seconds c3515_p19t at el 17.31 deg
# 2023-03-18 01:15:40.388 - tracking target for 900 seconds c3515_p19t at el 17.31 deg
# 2023-03-18 01:15:40.388 - slewing to target for 1.31 seconds J1833-2103 at el 31.40 deg
# 2023-03-18 01:30:41.701 - tracking target for 900 seconds J1833-2103 at el 31.40 deg
# 2023-03-18 01:30:41.701 - skipping c3515_p19t at el 11.29 deg deg
# 2023-03-18 01:30:41.701 - slewing to target for 1.03 seconds J1833-2103 at el 28.18 deg
# 2023-03-18 01:45:42.727 - tracking target for 900 seconds J1833-2103 at el 28.18 deg
# 2023-03-18 01:45:42.727 - skipping c3515_p19t at el 8.34 deg deg
# 2023-03-18 01:45:42.727 - slewing to target for 1.03 seconds J1833-2103 at el 24.98 deg
# 2023-03-18 02:00:43.754 - tracking target for 900 seconds J1833-2103 at el 24.98 deg
# 2023-03-18 02:00:43.754 - skipping c3515_p19t at el 5.43 deg deg
# 2023-03-18 02:00:43.754 - slewing to target for 1.03 seconds J1833-2103 at el 21.80 deg
# 2023-03-18 02:15:44.780 - tracking target for 900 seconds J1833-2103 at el 21.80 deg

# %%
simulator.plot_el()

# %%
simulator.show_summary()
# Out:
# c3515_p19t observed for 4:15:00
# J1833-2103 observed for 5:00:00
# total on target time: 9:15:00

# %%
array = ['W102', 'W4', 'W45', 'W173', 'W196', 'W392']
simulator.plot_uv(array, 'c3515_p19t')

# %%
simulator.plot_uv(array, 'J1833-2103')
